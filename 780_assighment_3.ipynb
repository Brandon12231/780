# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandon12231/780/blob/main/780_assighment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path=("https://github.com/soltaniehha/Intro-to-Data-Analytics/blob/main/data/AnalyticsEdge-Datasets/Framingham.csv")
import pandas as pd 
df=pd.read_csv('https://raw.githubusercontent.com/soltaniehha/Intro-to-Data-Analytics/main/data/AnalyticsEdge-Datasets/Framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
#1.Data cleaning and handling missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
#check for missing values
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#better to fill null with value because  on  education column has 105
df.fillna(df.mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4240 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4240 non-null   float64
#  5   BPMeds           4240 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4240 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4240 non-null   float64
#  13  heartRate        4240 non-null   float64
#  14  glucose          4240 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
import numpy as np
import pandas as pd
df.groupby('male')['cigsPerDay'].agg(np.mean)
# Out:
# male
# 0     5.750037
# 1    13.335211
# Name: cigsPerDay, dtype: float64

# %% [markdown]
# just wanna check ci man taking more cig per day

# %%
#Check which age group with most smoker
df.groupby('age')['currentSmoker'].agg(np.mean).sort_values()
# Out:
# age
# 70    0.000000
# 65    0.210526
# 66    0.263158
# 64    0.290323
# 63    0.300000
# 62    0.303030
# 61    0.327273
# 68    0.333333
# 55    0.344828
# 67    0.355556
# 59    0.361345
# 60    0.369369
# 52    0.389262
# 54    0.393939
# 33    0.400000
# 57    0.414634
# 53    0.424460
# 69    0.428571
# 56    0.447154
# 58    0.452991
# 48    0.508671
# 51    0.520548
# 50    0.521429
# 49    0.537879
# 35    0.547619
# 36    0.559524
# 46    0.576923
# 39    0.582353
# 41    0.586207
# 45    0.592593
# 37    0.608696
# 34    0.611111
# 42    0.611111
# 38    0.611111
# 44    0.620482
# 43    0.622642
# 40    0.630208
# 47    0.631206
# 32    1.000000
# Name: currentSmoker, dtype: float64

# %%
#age 32 has highest as 1, its seems imposible so i had this check how much people age 32,so there is only one
df[df['age']==32]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 2365     0   32        2.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 2365                0             0         0    242.0  111.0   70.0  29.84
#
#       heartRate  glucose  TenYearCHD
# 2365       80.0     88.0           0

# %%
import pandas as pd
pd.pivot_table(df, index=['age','sysBP'])
# Out:
#                  BMI  BPMeds  TenYearCHD  cigsPerDay  currentSmoker  diaBP  \
# age sysBP
# 32  111.0  29.840000     0.0         0.0        15.0            1.0   70.0
# 33  108.0  19.840000     0.0         0.0         0.0            0.0   67.0
#     116.0  21.610000     0.0         0.0        15.0            1.0   81.0
#     119.0  23.800000     0.0         0.0         5.0            1.0   74.0
#     136.0  24.950000     0.0         0.0         0.0            0.0   75.0
# ...              ...     ...         ...         ...            ...    ...
# 69  164.0  17.230000     0.0         0.0         0.0            0.0   80.0
#     166.0  25.400000     1.0         0.0         0.0            0.0   90.0
#     179.0  26.640000     0.0         0.0        23.0            1.0   93.0
# 70  136.0  31.780000     1.0         0.0         0.0            0.0   84.0
#     143.0  25.800801     0.0         1.0         0.0            0.0   93.0
#
# ...

# %%
#Check for smoking,age,diebetes related to  prevalentStroke or not
df_agg=df.groupby('prevalentStroke').agg({'age':['mean','median'],'currentSmoker':['mean'],'diabetes':['mean']})
df_agg
# Out:
#                        age        currentSmoker  diabetes
#                       mean median          mean      mean
# prevalentStroke
# 0                49.542112   49.0      0.495374  0.025623
# 1                56.000000   58.0      0.280000  0.040000

# %% [markdown]
# so we can tell order people more like to get precalentsroke,but seems not related to smoke, but for diabetes, its probpbility has been double on People with diabetes to prevalentStroke

# %%
#making a pivot table to check if prevalentsroke relate to gander
df.pivot_table(values='prevalentStroke', index='age', columns='male', aggfunc='mean')
# Out:
# male         0         1
# age
# 32    0.000000       NaN
# 33    0.000000  0.000000
# 34    0.000000  0.000000
# 35    0.000000  0.000000
# 36    0.000000  0.000000
# 37    0.000000  0.000000
# 38    0.000000  0.014493
# 39    0.000000  0.000000
# 40    0.000000  0.000000
# 41    0.010204  0.000000
# 42    0.009804  0.000000
# 43    0.000000  0.000000
# 44    0.000000  0.000000
# 45    0.000000  0.000000
# 46    0.000000  0.000000
# 47    0.011236  0.000000
# 48    0.000000  0.000000
# 49    0.000000  0.000000
# 50    0.000000  0.000000
# 51    0.000000  0.000000
# 52    0.025316  0.028571
# 53    0.012048  0.017857
# 54    0.012821  0.000000
# 55    0.000000  0.000000
# 56    0.000000  0.018868
# 57    0.000000  0.000000
# 58    0.029851  0.020000
# 59    0.000000  0.000000
# 60    0.033333  0.019608
# 61    0.014925  0.000000
# 62    0.000000  0.000000
# 63    0.014493  0.024390
# 64    0.000000  0.000000
# 65    0.027778  0.047619
# 66    0.000000  0.000000
# ...

# %%
x=df[df['prevalentStroke']==1]

# %% [markdown]
# from the table,man have more probability to get prevalentStroke

# %%
#Check if older people are prone to obesity
sns.relplot(x='age', y='BMI',  data=df)

# %%
#2.Create a histplot of age vs. 'prevalentStroke' to check if older people are more likey to get prevalentStroke
import seaborn as sns
sns.histplot(data=df,x='age',y='prevalentStroke')

# %%
#3.diabetes over ages for diff gender

sns.lineplot(x='age', y='diabetes',  data=df, hue='male')

# %% [markdown]
# When men reach old age, they are far more likely to get diabetes than women

# %%
#4.Create a relplot of prevalentStroke over ages in diff gender
sns.relplot(x='prevalentStroke', y='age',  data=df, hue='male', col='currentSmoker')

# %% [markdown]
# this plot show more clearly, smoke does not effect prevalentsroke much, but gender indeed

# %%
#5.i wanna check is it more possible to get stoke if people keep high bmi 
sns.relplot(x='age', y='BMI',  data=x, hue='male', col='currentSmoker',style='prevalentStroke')

# %% [markdown]
# There is no greater and denser likelihood of prevalentsroke for high bmi older people ,combine the age and gender and smoke to check relation between those with prevalentsroke, so man do smoke more than women,but doesnt mean smoke will contibute to prevalentsroke
